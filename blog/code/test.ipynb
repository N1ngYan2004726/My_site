# %% [markdown]
# ---
# title: "test"
# description: "这是一个测试页面"
# date: 2026-08-31
#
# categories:
#   - mathematics
#   - linear-algebra
# ---
#
# 这是一个测试内容。这是一个测试内容。这是一个测试内容。这是一个测试内容。这是一个测试内容。这是一个测试内容。这是一个测试内容。这是一个测试内容。这是一个测试内容。这是一个测试内容。这是一个测试内容。这是一个测试内容。
#
# ```{pyodide}
# #| caption: "在线练习"
# a = 10
# b = 20
#
# print(a + b)
# ```
